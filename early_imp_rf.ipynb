# %%
# libraries
import pandas as pd
import numpy as np

# %%
# read data set

imp = pd.read_csv('//babylon/visitors/tjsipin/MacDonald-REU-Summer-22/gap_inp_early_2.csv')

# %%
imp.head()
# Out:
#    Year   Country  Population  Cutaneous.Leishmaniasis    Dengue   Malaria  \
# 0  2007  Colombia     1801730                 0.000555  0.002775  0.002220
# 1  2008  Colombia     1839334                 0.005980  0.493657  0.010874
# 2  2009  Colombia     1894391                 0.001584  0.218012  0.009502
# 3  2010  Colombia     1937458                 0.003097  8.036303  0.018065
# 4  2011  Colombia     1960132                 0.003061  0.409156  0.005102
#
#    Mucosal.Leishmaniasis  Visceral.Leishmaniasis  Yellow.Fever    LST_Day  \
# 0                0.00000                     0.0           0.0  24.086593
# 1                0.00000                     0.0           0.0  23.432834
# 2                0.00000                     0.0           0.0  23.803182
# 3                0.00000                     0.0           0.0  24.686513
# 4                0.00051                     0.0           0.0  23.795693
#
#    ...  Dengue_Aeg_OptTemp  Chik_Alb_OptTemp  Chik_Aeg_OptTemp  Zika_OptTemp  \
# 0  ...                   0                14                 0             0
# 1  ...                   0                 8                 0             0
# 2  ...                   1                 9                 1             1
# 3  ...                   2                19                 2             2
# 4  ...                   0                13                 0             0
#
#    Malaria_OptTemp      NDVI       EVI       Precip  StableLights  \
# 0               22  0.500981  0.304495  2087.610085     37.972903
# 1                9  0.475580  0.287916  2553.313095     20.001042
# 2               16  0.527427  0.329218  1812.452090     38.951077
# 3               22  0.499809  0.312449  2402.545373     45.657085
# 4               18  0.492869  0.322488  2430.899353     40.699944
#
#    SWOccurrence
# 0     17.033807
# 1     17.033807
# 2     17.033807
# 3     17.033807
# 4     17.033807
#
# [5 rows x 23 columns]

# %%
# Descriptive statistics for each column
imp.describe()
# Out:
#                Year    Population  Cutaneous.Leishmaniasis        Dengue  \
# count  31887.000000  3.188700e+04             31887.000000  31887.000000
# mean    2007.424499  4.810063e+04                 0.944172      2.938452
# std        3.793120  2.570814e+05                 2.256622      8.199956
# min     2001.000000  1.960000e+02                 0.000555      0.000000
# 25%     2004.000000  6.850000e+03                 0.091542      0.000000
# 50%     2008.000000  1.397900e+04                 0.278242      0.336247
# 75%     2011.000000  2.887150e+04                 0.866155      2.048545
# max     2013.000000  9.895449e+06                91.746021    192.048518
#
#             Malaria  Mucosal.Leishmaniasis  Visceral.Leishmaniasis  \
# count  31887.000000           3.188700e+04            3.188700e+04
# mean       5.713056           3.241586e-02            3.112830e-02
# std       36.558068           9.212280e-02            1.105319e-01
# min        0.000000          -9.325873e-17           -2.867498e-16
# 25%        0.000000           3.995702e-03            0.000000e+00
# 50%        0.000000           9.289994e-03            0.000000e+00
# 75%        0.048416           2.543914e-02            0.000000e+00
# max     1535.365979           3.194888e+00            2.743955e+00
#
#        Yellow.Fever       LST_Day     LST_Night  ...  Dengue_Aeg_OptTemp  \
# count  3.188700e+04  31887.000000  31887.000000  ...        31887.000000
# mean   5.529735e-04     28.674784     18.372015  ...            8.249130
# std    2.081193e-02      3.253400      3.865745  ...            5.155187
# min   -2.263543e-17     11.213812     -2.752709  ...            0.000000
# 25%    0.000000e+00     26.896206     16.788056  ...            5.000000
# 50%    0.000000e+00     28.975936     19.128340  ...            8.000000
# 75%    0.000000e+00     31.005919     21.049372  ...           12.000000
# max    2.088409e+00     42.284843     24.972378  ...           30.000000
#
#        Chik_Alb_OptTemp  Chik_Aeg_OptTemp  Zika_OptTemp  Malaria_OptTemp  \
# count      31887.000000      31887.000000  31887.000000     31887.000000
# mean          11.264371          8.249130      8.249130         9.041145
# std            8.040556          5.155187      5.155187         7.308774
# min            0.000000          0.000000      0.000000         0.000000
# 25%            5.000000          5.000000      5.000000         3.000000
# 50%           11.000000          8.000000      8.000000         8.000000
# 75%           16.000000         12.000000     12.000000        14.000000
# max           44.000000         30.000000     30.000000        42.000000
#
#                NDVI           EVI        Precip  StableLights  SWOccurrence
# count  31887.000000  31887.000000  31887.000000  31887.000000  31887.000000
# mean       0.608978      0.392105   1549.371957      3.704156     35.377127
# std        0.086126      0.066292    760.737413      8.674027     23.073426
# min        0.076620      0.048846      0.000000      0.000000      0.000000
# 25%        0.565609      0.354735   1129.466975      0.175802     16.563696
# 50%        0.613781      0.395381   1430.004880      0.672119     29.800273
# 75%        0.665272      0.439420   1816.305773      2.729931     50.928932
# max        0.841319      0.560872   8613.400188     63.000000     97.943103
#
# [8 rows x 22 columns]

# %%
aad.describe()
# Out:
#                Code           Year    Population   Chikungunya  \
# count  1.711400e+05  171140.000000  1.711400e+05  13845.000000
# mean   2.143807e+06    2009.500000  2.682784e+04      0.246878
# std    1.708727e+06       5.766298  1.627907e+05      2.654742
# min    5.001000e+03    2000.000000  9.800000e+01      0.000000
# 25%    1.103030e+05    2004.750000  3.735000e+03      0.000000
# 50%    2.503555e+06    2009.500000  8.277000e+03      0.000000
# 75%    3.514403e+06    2014.250000  1.849100e+04      0.000000
# max    5.300108e+06    2019.000000  1.035358e+07    172.139303
#
#        Cutaneous.Leishmaniasis         Dengue        Malaria  \
# count            131202.000000  125638.000000  136766.000000
# mean                  0.343305       2.583887       1.634192
# std                   1.510583       8.493871      18.866805
# min                   0.000000       0.000000       0.000000
# 25%                   0.000000       0.000000       0.000000
# 50%                   0.000000       0.124899       0.000000
# 75%                   0.112999       1.299275       0.000000
# max                  91.746021     379.199864    1535.365979
#
#        Mucosal.Leishmaniasis  Visceral.Leishmaniasis   Yellow.Fever  ...  \
# count           31050.000000           112472.000000  100224.000000  ...
# mean                0.019548                0.022124       0.000256  ...
# std                 0.147743                0.094924       0.014002  ...
# min                 0.000000                0.000000       0.000000  ...
# 25%                 0.000000                0.000000       0.000000  ...
# 50%                 0.000000                0.000000       0.000000  ...
# 75%                 0.000000                0.000000       0.000000  ...
# max                 5.425631                5.350195       2.088409  ...
#
#        Savanna_Riverlakeocean  Floodforest_Wetland  Floodforest_Farming  \
# count            38862.000000         3.886200e+04         38862.000000
# mean               359.432582         3.061520e+03            95.940147
# std               1908.244556         3.197677e+04           889.582216
# min                  0.000000         0.000000e+00             0.000000
# 25%                  0.000000         0.000000e+00             0.000000
# 50%                  0.000000         0.000000e+00             0.000000
# 75%                  0.000000         0.000000e+00             0.000000
# max              52408.000000         1.676670e+06         30657.000000
#
#        Floodforest_Nonveg  Floodforest_Riverlakeocean  Wetland_Farming  \
# count        38862.000000                38862.000000     38862.000000
# mean             1.703927                   84.505584       114.306958
# std             17.309983                  776.102713      1865.146088
# min              0.000000                    0.000000         0.000000
# 25%              0.000000                    0.000000         0.000000
# 50%              0.000000                    0.000000         0.000000
# 75%              0.000000                    0.000000         0.000000
# max            692.000000                23942.000000    121813.000000
#
#        Wetland_Nonveg  Farming_Nonveg  Farming_Riverlakeocean  \
# count    38862.000000    38862.000000            38862.000000
# mean        41.903402     3125.659462             1506.249318
# std        224.636149     7115.279714             4838.867423
# min          0.000000        0.000000                0.000000
# 25%          0.000000       22.000000               12.000000
# 50%          0.000000      531.000000              129.000000
# 75%          0.000000     2913.750000              816.000000
# max       6451.000000   148015.000000           200322.000000
#
#        Nonveg_Riverlakeocean
# count           38862.000000
# mean              736.545340
# std              2423.235964
# min                 0.000000
# 25%                 0.000000
# 50%                61.000000
# 75%               459.000000
# max             96656.000000
#
# [8 rows x 67 columns]

# %%
imp = pd.get_dummies(imp)
imp.columns
# Out:
# Index(['Year', 'Population', 'Cutaneous.Leishmaniasis', 'Dengue', 'Malaria',
#        'Mucosal.Leishmaniasis', 'Visceral.Leishmaniasis', 'Yellow.Fever',
#        'LST_Day', 'LST_Night', 'OptTemp_Obs', 'Dengue_Alb_OptTemp',
#        'Dengue_Aeg_OptTemp', 'Chik_Alb_OptTemp', 'Chik_Aeg_OptTemp',
#        'Zika_OptTemp', 'Malaria_OptTemp', 'NDVI', 'EVI', 'Precip',
#        'StableLights', 'SWOccurrence', 'Country_Brazil', 'Country_Colombia',
#        'Country_Peru'],
#       dtype='object')

# %%
# use numpy to convert to arrays

# labels are the values we want to predict
labels = np.array(imp['Cutaneous.Leishmaniasis'])

# remove the labels from the features
# axis 1 refers to the columns
features = imp.drop('Cutaneous.Leishmaniasis', axis = 1)

# saving feature names for later use
feature_list = list(features.columns)

# convert features to numpy array
features = np.array(features)

# %%
# using Scikit-learn to split data into training and testing sets
from sklearn.model_selection import train_test_split

# split the data into training and testing sets
train_features, test_features, train_labels, test_labels = train_test_split(
    features, 
    labels, 
    test_size=0.25,
    random_state=42)

print('Training Features Shape: ', train_features.shape)
print('Training Labels Shape: ', train_labels.shape)
print('Testing Features Shape: ', test_features.shape)
print('Testing Labels Shape: ', test_labels.shape)
# Out:
# Training Features Shape:  (23915, 24)
# Training Labels Shape:  (23915,)
# Testing Features Shape:  (7972, 24)
# Testing Labels Shape:  (7972,)

# %%
# repeated random subsampling
